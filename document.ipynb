# %% [markdown]
# LOAD PDF's (Document Loader)

# %%
## import required class

from langchain_community.document_loaders import PyPDFLoader ##reads PDF files page by page
import os ##helps to navigate folders and files                                                                                                                   ##Function to Load PDFs

def load_medical_pdfs(pdf_folder_path):
    print(pdf_folder_path)                                                                                                                                        documents=[]                                                                                                                                                                import os
pdf_folder_path = "../data/pdf" 

pdf_files = []

for file_name in os.listdir(pdf_folder_path):
    if file_name.endswith(".pdf"):
        pdf_files.append(file_name)

pdf_files                                                                                                                                                     ## load each pdf

loader = PyPDFLoader("../data/pdf/Antenatal care guidelines.pdf")
pdf_docs = loader.load()
print(pdf_docs)
## to all all pdfs 
all_docs = []
for f in os.listdir("../data/pdf"):
    if f.endswith(".pdf"):
        all_docs.extend(PyPDFLoader(os.path.join("../data/pdf", f)).load())
        print(all_docs)                                 
     documents.extend(pdf_docs)
print(len(documents))
print(f"Total pages loaded: {len(documents)}")
print(documents[0])                                                                                                                              documents = []

for file_name in os.listdir(pdf_folder_path):
    if file_name.endswith(".pdf"):
        loader = PyPDFLoader(os.path.join(pdf_folder_path, file_name))
        docs = loader.load()

        for doc in docs:
            doc.metadata["source"] = file_name

        documents.extend(docs)
        documents[0].metadata                                                                                                                  print(f"Total pages loaded: {len(documents)}")                                                                                                from collections import Counter

pdf_summary = Counter(doc.metadata["source"] for doc in documents)

for pdf, pages in pdf_summary.items():
    print(f"{pdf} → {pages} pages")
print(f"Total pages loaded: {len(docs)}")
print(docs[0])                                                                                                                                               !pip install langchain-text-splitters                                                                                                                       from langchain_text_splitters import RecursiveCharacterTextSplitter                                                              text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,    
    chunk_overlap=200
)
 chunks = text_splitter.split_documents(documents)                                                                      print(f"Number of chunks created: {len(chunks)}") 
print(chunks[0].page_content[:500])                                                                 
print(chunks[0].page_content[-200:]) 
print(chunks[1].page_content[:200])                                                                                                                       from sentence_transformers import SentenceTransformer 

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

print("Model loaded successfully")                                                                                                                            from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS                                                                                            embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)vectorstore = FAISS.from_documents(
    documents=chunks,
    embedding=embedding_model
)vectorstore.save_local("faiss_index")
uery = "How is diabetes treated?"

results = vectorstore.similarity_search(query, k=3)

for doc in results:
    print(doc.page_content[:300])
    print(doc.metadata)
    print("-" * 40)
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)faiss_db = FAISS.from_documents(
    documents=chunks,
    embedding=embedding_model
)faiss_db.save_local("faiss_index")
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
chroma_db = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model,
    persist_directory="./chroma_db"
)
chroma_db.persist()                                                                                                                                              query = "How can we take care a mother after a child birth?" 

results = faiss_db.similarity_search(query, k=3)

for doc in results:
    print(doc.page_content[:200])
    print(doc.metadata)
    print("-" * 40)                                                                                                                                                        pip install langchain langchain-community openai  
 from langchain_openai import ChatOpenAI                                                                                                                                      retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}
)
## inspect retrievered documents
retrieved_docs = retriever.invoke(
    "What are the treatments for diabetes?"
)

for i, doc in enumerate(retrieved_docs):
    print(f"Doc {i+1}")
    print(doc.page_content[:200])
    print(doc.metadata)
    print("-" * 40)
## duplicate and noise removal
 def remove_duplicates(docs):
    seen = set()
    unique_docs = []

    for doc in docs:
        content = doc.page_content.strip()
        if content not in seen:
            unique_docs.append(doc)
            seen.add(content)

    return unique_docs


clean_docs = remove_duplicates(retrieved_docs)
def filter_by_source(docs, allowed_sources):
    return [
        doc for doc in docs
        if doc.metadata.get("source") in allowed_sources
    ]


trusted_docs = filter_by_source(
    clean_docs,
    allowed_sources=[
        "who_guidelines.pdf",
        "clinical_protocols.pdf"
    ]
)
def build_context(docs, max_chars=3000):
    context = ""
    for doc in docs:
        if len(context) + len(doc.page_content) <= max_chars:
            context += doc.page_content + "\n\n"
    return context


final_context = build_context(trusted_docs)
def safety_check(query):
    restricted_terms = ["dosage", "prescription", "self-medication"]
    for term in restricted_terms:
        if term in query.lower():
            return False
    return True
if not safety_check(query):
    print("⚠️ This question requires a medical professional.")
chatbot_prompt = f"""
You are a healthcare assistant chatbot.
Answer ONLY from the provided context.
If not found, say you don't know.

Context:
{final_context}

Answer the user's question clearly and safely.
"""
explain this code step by step clearly and what happens internally and what will be the output and why these steps are required in this project and what happens if we dont use these steps

# %%
## import required class

from langchain_community.document_loaders import PyPDFLoader ##reads PDF files page by page
import os ##helps to navigate folders and files

# %%
##Function to Load PDFs

def load_medical_pdfs(pdf_folder_path):
    print(pdf_folder_path)

# %%
## create empty list to store langchain document objects

documents=[]

# %%
import os
pdf_folder_path = "../data/pdf" 

pdf_files = []

for file_name in os.listdir(pdf_folder_path):
    if file_name.endswith(".pdf"):
        pdf_files.append(file_name)

# %%
## load each pdf

loader = PyPDFLoader("../data/pdf/Antenatal care guidelines.pdf")
pdf_docs = loader.load()

# %%
## to all all pdfs 
all_docs = []
for f in os.listdir("../data/pdf"):
    if f.endswith(".pdf"):
        all_docs.extend(PyPDFLoader(os.path.join("../data/pdf", f)).load())

# %%
## combine all pdfs

documents.extend(pdf_docs)
print(len(documents))
# Out:
# 24

# %%
print(f"Total pages loaded: {len(documents)}")
# Out:
# Total pages loaded: 698

# %%
documents = []

for file_name in os.listdir(pdf_folder_path):
    if file_name.endswith(".pdf"):
        loader = PyPDFLoader(os.path.join(pdf_folder_path, file_name))
        docs = loader.load()

        for doc in docs:
            doc.metadata["source"] = file_name

        documents.extend(docs)
        documents[0].metadata

# %%
print(f"Total pages loaded: {len(documents)}")
# Out:
# Total pages loaded: 698

# %%
from collections import Counter

pdf_summary = Counter(doc.metadata["source"] for doc in documents)

for pdf, pages in pdf_summary.items():
    print(f"{pdf} → {pages} pages")
# Out:
# Antenatal care guidelines.pdf → 24 pages
# clinical management of COVID-19.pdf → 5 pages
# depression management guidelines.pdf → 17 pages
# diabetes management.pdf → 35 pages
# integrated management of pregnancy and childbirth.pdf → 492 pages
# postnatal care guidelines.pdf → 8 pages
# prevention of cardiovascular disease.pdf → 20 pages
# Tuberculosis guidelines WHO.pdf → 74 pages
# vaccination guidelines.pdf → 14 pages
# WHO-Hypertension-guidelines.pdf → 9 pages

# %%
print(f"Total pages loaded: {len(docs)}")
# Out:
# Total pages loaded: 9

# %%
# !pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in D:\RAGproject\.venv\Lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in D:\RAGproject\.venv\Lib\site-packages (from langchain-text-splitters) (1.2.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.6.8)
# Requirement already satisfied: packaging>=23.2.0 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\RAGproject\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in D:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in D:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in D:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in D:\RAGproject\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.12.1)
# Requirement already satisfied: certifi in D:\RAGproject\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in D:\RAGproject\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in D:\RAGproject\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in D:\RAGproject\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\RAGproject\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\RAGproject\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\RAGproject\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\RAGproject\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\RAGproject\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.6.3)

# %% [markdown]
# CHUNKING

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,    
    chunk_overlap=200
)

# %%
chunks = text_splitter.split_documents(documents)

# %%
print(f"Number of chunks created: {len(chunks)}")
print(chunks[0].page_content[:500])
# Out:
# Number of chunks created: 1613
# WHO recommendations
# on antenatal care for a positive pregnancy experience:
# web annexes*
# * The full guideline document is available at: http:/ /www.who.int/ reproductivehealth/ publications/ maternal_perinatal_health/ anc-positive-pregnancy-experience/ en/

# %%
print(chunks[0].page_content[-200:])
print(chunks[1].page_content[:200])
# Out:
# nancy experience:
# web annexes*
# * The full guideline document is available at: http:/ /www.who.int/ reproductivehealth/ publications/ maternal_perinatal_health/ anc-positive-pregnancy-experience/ en/
# WHO Library Cataloguing-in-Publication Data
# WHO recommendations on antenatal care for a positive pregnancy experience.
# I.World Health Organization.
# ISBN 978 92 4 154991 2
# Subject headings are availabl

# %% [markdown]
# EMBEDDINGS

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

print("Model loaded successfully")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded successfully

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10400\3825674162.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
vectorstore = FAISS.from_documents(
    documents=chunks,
    embedding=embedding_model
)

# %%
vectorstore.save_local("faiss_index")

# %%
print("Embeddings created and vector store saved successfully!")
# Out:
# Embeddings created and vector store saved successfully!

# %%
query = "How is diabetes treated?"

results = vectorstore.similarity_search(query, k=3)

for doc in results:
    print(doc.page_content[:300])
    print(doc.metadata)
    print("-" * 40)
# Out:
# and resources allow.
# Treatment
# The major components of the treatment of diabetes are:
# 1. diet (combined with exercise if possible)
# 2. oral hypoglycaemic therapy
# 3. insulin treatment
# Education of the person with diabetes is an essential component of management in
# every case. To ensure appropriate ma
# {'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2006-01-05T11:00:54+02:00', 'moddate': '2006-01-05T11:00:54+02:00', 'title': 'http://www.emro.who.int/ncd/publications/diabetesmanagement.pdf', 'author': 'zianf', 'source': 'diabetes management.pdf', 'total_pages': 35, 'page': 8, 'page_label': '9'}
# ----------------------------------------
# WHO-EM/DIN6/E/G
# MANAGEMENT OF NON-
# INSULIN-DEPENDENT
# DIABETES MELLITUS
# Basic principles
# • Correct diagnosis is essential. Thus emphasis should be placed on using appropriate
# diagnostic criteria.
#  Treatment should not only consider lowering the blood glucose level but also should
# focus on the corr
# {'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2006-01-05T11:00:54+02:00', 'moddate': '2006-01-05T11:00:54+02:00', 'title': 'http://www.emro.who.int/ncd/publications/diabetesmanagement.pdf', 'author': 'zianf', 'source': 'diabetes management.pdf', 'total_pages': 35, 'page': 3, 'page_label': '4'}
# ----------------------------------------
# of morbidity, disability and premature death in countries of this Region.
# The development of long-term complications is influenced by hyperglycaernia. Poor
# control of diabetes accelerates their progression. Thus, to prevent complications, good
# control of diabetes is essential and the management of
# {'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2006-01-05T11:00:54+02:00', 'moddate': '2006-01-05T11:00:54+02:00', 'title': 'http://www.emro.who.int/ncd/publications/diabetesmanagement.pdf', 'author': 'zianf', 'source': 'diabetes management.pdf', 'total_pages': 35, 'page': 1, 'page_label': '2'}
# ----------------------------------------

# %% [markdown]
# VECTOR DATABASE

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
faiss_db = FAISS.from_documents(
    documents=chunks,
    embedding=embedding_model
)

# %%
faiss_db.save_local("faiss_index")

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
chroma_db = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model,
    persist_directory="./chroma_db"
)

# %%
chroma_db.persist()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10400\4212842399.py:1: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   chroma_db.persist()

# %%
query = "How can we take care a mother after a child birth?"

results = faiss_db.similarity_search(query, k=3)

for doc in results:
    print(doc.page_content[:200])
    print(doc.metadata)
    print("-" * 40)
# Out:
# emphasize respectful and women-centred maternity care.
# 11 Strategies to
# improve quality and achieve equitable use of postnatal care should be
# selected to maximize population-level results in low-res
# {'producer': 'Acrobat Distiller 11.0 (Windows)', 'creator': 'PScript5.dll Version 5.2.2', 'creationdate': '2015-05-29T08:36:10-04:00', 'author': 'rwalsh', 'moddate': '2015-05-29T08:36:10-04:00', 'title': 'Microsoft Word - WHO PNC 2014 Briefer_A4.docx', 'source': 'postnatal care guidelines.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}
# ----------------------------------------
# recommendations on which type of health care worker can safely deliver key maternal and newborn health care
# interventions,10 which went through a similar guidelines development process.
# Although th
# {'producer': 'Acrobat Distiller 11.0 (Windows)', 'creator': 'PScript5.dll Version 5.2.2', 'creationdate': '2015-05-29T08:36:10-04:00', 'author': 'rwalsh', 'moddate': '2015-05-29T08:36:10-04:00', 'title': 'Microsoft Word - WHO PNC 2014 Briefer_A4.docx', 'source': 'postnatal care guidelines.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}
# ----------------------------------------
# simultaneous essential newborn care.
# Note: Only clamp the cord early (within one minute) if the newborn needs
# to be moved immediately for resuscitation.
# • Ensure that the baby is kept warm and in
# {'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 14.0 (Macintosh)', 'creationdate': '2019-03-15T11:39:31+01:00', 'moddate': '2019-03-15T11:49:03+01:00', 'trapped': '/False', 'source': 'integrated management of pregnancy and childbirth.pdf', 'total_pages': 492, 'page': 124, 'page_label': '125'}
# ----------------------------------------

# %% [markdown]
# RETRIEVER + QA CHAIN

# %%
pip install langchain langchain-community openai
# Out:
# Requirement already satisfied: langchain in d:\RAGproject\.venv\Lib\site-packages (1.2.8)
# Requirement already satisfied: langchain-community in d:\RAGproject\.venv\Lib\site-packages (0.4.1)
# Requirement already satisfied: openai in d:\RAGproject\.venv\Lib\site-packages (2.16.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in d:\RAGproject\.venv\Lib\site-packages (from langchain) (1.2.8)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in d:\RAGproject\.venv\Lib\site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\RAGproject\.venv\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (0.6.8)
# Requirement already satisfied: packaging>=23.2.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\RAGproject\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\RAGproject\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in d:\RAGproject\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\RAGproject\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in d:\RAGproject\.venv\Lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\RAGproject\.venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\RAGproject\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in d:\RAGproject\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\RAGproject\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\RAGproject\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (4.12.1)
# Requirement already satisfied: certifi in d:\RAGproject\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\RAGproject\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\RAGproject\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\RAGproject\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\RAGproject\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\RAGproject\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\RAGproject\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\RAGproject\.venv\Lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in d:\RAGproject\.venv\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\RAGproject\.venv\Lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in d:\RAGproject\.venv\Lib\site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\RAGproject\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\RAGproject\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\RAGproject\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\RAGproject\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\RAGproject\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\RAGproject\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\RAGproject\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\RAGproject\.venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\RAGproject\.venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in d:\RAGproject\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\RAGproject\.venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\RAGproject\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\RAGproject\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in d:\RAGproject\.venv\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\RAGproject\.venv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\RAGproject\.venv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\RAGproject\.venv\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in d:\RAGproject\.venv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\RAGproject\.venv\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: colorama in d:\RAGproject\.venv\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI

# %% [markdown]
# RETRIEVER

# %%
# Convert vector DB into retriever
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}
)

# %%
## inspect retrievered documents
retrieved_docs = retriever.invoke(
    "What are the treatments for diabetes?"
)

for i, doc in enumerate(retrieved_docs):
    print(f"Doc {i+1}")
    print(doc.page_content[:200])
    print(doc.metadata)
    print("-" * 40)
# Out:
# Doc 1
# and resources allow.
# Treatment
# The major components of the treatment of diabetes are:
# 1. diet (combined with exercise if possible)
# 2. oral hypoglycaemic therapy
# 3. insulin treatment
# Education of the p
# {'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2006-01-05T11:00:54+02:00', 'moddate': '2006-01-05T11:00:54+02:00', 'title': 'http://www.emro.who.int/ncd/publications/diabetesmanagement.pdf', 'author': 'zianf', 'source': 'diabetes management.pdf', 'total_pages': 35, 'page': 8, 'page_label': '9'}
# ----------------------------------------
# Doc 2
# of morbidity, disability and premature death in countries of this Region.
# The development of long-term complications is influenced by hyperglycaernia. Poor
# control of diabetes accelerates their progr
# {'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2006-01-05T11:00:54+02:00', 'moddate': '2006-01-05T11:00:54+02:00', 'title': 'http://www.emro.who.int/ncd/publications/diabetesmanagement.pdf', 'author': 'zianf', 'source': 'diabetes management.pdf', 'total_pages': 35, 'page': 1, 'page_label': '2'}
# ----------------------------------------
# Doc 3
# WHO-EM/DIN6/E/G
# MANAGEMENT OF NON-
# INSULIN-DEPENDENT
# DIABETES MELLITUS
# Basic principles
# • Correct diagnosis is essential. Thus emphasis should be placed on using appropriate
# diagnostic criteria.
#  Tr
# {'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2006-01-05T11:00:54+02:00', 'moddate': '2006-01-05T11:00:54+02:00', 'title': 'http://www.emro.who.int/ncd/publications/diabetesmanagement.pdf', 'author': 'zianf', 'source': 'diabetes management.pdf', 'total_pages': 35, 'page': 3, 'page_label': '4'}
# ----------------------------------------
# Doc 4
# American Diabetes Association, Diabetes Care, Vol. 17, No. 5, 1994.
# 8. The prevention and treatment of complications of diabetes. A guide for primary care
# practitioners. Centres for Disease Control,
# {'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2006-01-05T11:00:54+02:00', 'moddate': '2006-01-05T11:00:54+02:00', 'title': 'http://www.emro.who.int/ncd/publications/diabetesmanagement.pdf', 'author': 'zianf', 'source': 'diabetes management.pdf', 'total_pages': 35, 'page': 33, 'page_label': '34'}
# ----------------------------------------

# %%
 ## duplicate and noise removal
 def remove_duplicates(docs):
    seen = set()
    unique_docs = []

    for doc in docs:
        content = doc.page_content.strip()
        if content not in seen:
            unique_docs.append(doc)
            seen.add(content)

    return unique_docs


clean_docs = remove_duplicates(retrieved_docs)

# %%
def filter_by_source(docs, allowed_sources):
    return [
        doc for doc in docs
        if doc.metadata.get("source") in allowed_sources
    ]


trusted_docs = filter_by_source(
    clean_docs,
    allowed_sources=[
        "who_guidelines.pdf",
        "clinical_protocols.pdf"
    ]
)

# %%
def build_context(docs, max_chars=3000):
    context = ""
    for doc in docs:
        if len(context) + len(doc.page_content) <= max_chars:
            context += doc.page_content + "\n\n"
    return context


final_context = build_context(trusted_docs)

# %%
def safety_check(query):
    restricted_terms = ["dosage", "prescription", "self-medication"]
    for term in restricted_terms:
        if term in query.lower():
            return False
    return True

# %%
if not safety_check(query):
    print("⚠️ This question requires a medical professional.")

# %%
chatbot_prompt = f"""
You are a healthcare assistant chatbot.
Answer ONLY from the provided context.
If not found, say you don't know.

Context:
{final_context}

Answer the user's question clearly and safely.
"""

# %%
query = "Can insulin dosage be adjusted at home?"

if not safety_check(query):
    print("⚠️ This question requires guidance from a qualified medical professional.")
else:
    print("I don’t know based on the provided context.")
# Out:
# ⚠️ This question requires guidance from a qualified medical professional.
